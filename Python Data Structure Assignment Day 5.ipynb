# %% [markdown]
# <a id='1'></a><center> <h3 style="background-color:orange; color:white" ><br>Python Data Structures<br></h3>

# %% [markdown]
# # `Types of Data Structures:`
# * `List` | `Tuple`
# * `Set` | `Dictionary`

# %% [markdown]
# |Data Structures type|Mutable|Comments|Indexing|Ordered|Duplicacy|
# |----|----|----|----|----|----|
# tuple ()|immutable|immutable version of list| possible|yes |allowed |
# list []|mutable|-|possible |yes | allowed |
# set {}|mutable| -|not |no |not |
# dict {key:value}|mutable|-|possible |no |not  |

# %% [markdown]
# 💫 `immutable` => `can't be changed` <br>
# 💫 `mutable` => `can be changed`

# %%
print("Hello, Akshu")
# Out:
# Hello, Akshu

# %% [markdown]
# ## Lists

# %% [markdown]
# ### Create an empty list with the name ‘a’, print the value of a and type(a).

# %%
# create empty list, name it 'a'
a = []

# %%
# print the value of a
print(a)
# Out:
# []

# %%
# print the type of a
print(type(a))
# Out:
# <class 'list'>

# %% [markdown]
# ### Create a list , languages = ['R','Python', 'SAS', 'Scala', 42],

# %%
akshu = ['akshu', 30, 10] 
print(akshu)
type(akshu)
# Out:
# ['akshu', 30, 10]
# list

# %%
languages = ['R', 'Python', 'SAS', 'Scala',42]
print(languages)
# Out:
# ['R', 'Python', 'SAS', 'Scala', 42]

# %% [markdown]
# Print the number of elements in the list

# %%
Akshu = ['Akshu', 'Mani', 1, 2, 3, 20]
print(len(Akshu))
# Out:
# 6

# %% [markdown]
# Using for loop iterate and print all the elements in the list

# %%
for i in range(len(Akshu)):
    print(Akshu[i])
# Out:
# Akshu
# Mani
# 1
# 2
# 3
# 20

# %% [markdown]
# Select the second item, 'Python' and store it in a new variable named 'temp'

# %%
python = ["Java", "Python", "C++", "DSS"]
temp = python[1]
print(temp)
# Out:
# Python

# %% [markdown]
# Print the value of temp and type(temp)

# %%
python = ["Python", "Java", "C++", "DSS"]
python[1] = "R"
print(python)
# Out:
# ['Python', 'R', 'C++', 'DSS']

# %% [markdown]
# Append the element 'Java' in the list

# %%
my_list = ["Akshu", "Mani", "Reddy"]
my_list.append("Akshu")
print(my_list)
# Out:
# ['Akshu', 'Mani', 'Reddy', 'Akshu']

# %% [markdown]
# Remove the element 42 from the list and print the list

# %%
my_list = [10, 15, 20, 25, 30,"Akshu", "Mani"]
my_list.remove(20)
print(my_list)
# Out:
# [10, 15, 25, 30, 'Akshu', 'Mani']

# %% [markdown]
# ### Create a list, colors = [‘Red’, ‘Blue’, ‘White’]

# %%
colors = ['Red', 'Blue', 'White']

print(colors)
# Out:
# ['Red', 'Blue', 'White']

# %% [markdown]
# Append the element 'Black' to colors

# %%
colours = ["Red", "Blue", "White"]
colours.append("Black")
print(colours)
# Out:
# ['Red', 'Blue', 'White', 'Black']

# %% [markdown]
# Append the color 'Orange' to second position (index=1) and print the list

# %%
colours = ["Red", "Blue", "White"]
colours.append("orange")
colours.insert(1, "orange")
print(colours)
# Out:
# ['Red', 'orange', 'Blue', 'White', 'orange']

# %% [markdown]
# Print the list

# %%
colors = ["grey", "skyblue", "White", "Red"]
print(colors)
# Out:
# ['grey', 'skyblue', 'White', 'Red']

# %% [markdown]
# Create another list, colors2 = [‘Grey’, ‘Sky Blue’]

# %%
colors1 =["White", "Red"]
colors2 = ["Grey", "Skyblue"]

print(colors1)
print(colors2)
# Out:
# ['White', 'Red']
# ['Grey', 'Skyblue']

# %% [markdown]
# Add the elements of colors2 to colors using extend function in the list

# %%
colors1 =["White", "Red"]
colors2 = ["Grey", "Skyblue"]
colors.extend(colors2)
print(colors)
# Out:
# ['grey', 'skyblue', 'White', 'Red', 'Grey', 'Skyblue']

# %% [markdown]
# Print len of colors and its elements

# %%
colors1 =["White", "Red"]
colors2 = ["Grey", "Skyblue"]
colors.extend(colors2)
print(len(colors))
# Out:
# 8

# %% [markdown]
# Sort the list and print it.

# %%
colors =["White", "Red", "Grey", "Skyblue"]

colors.sort()

print(colors)
# Out:
# ['Grey', 'Red', 'Skyblue', 'White']

# %% [markdown]
# ### Create a string, sent = ‘Coronavirus Caused Lockdowns Around The World.”

# %%
sent = "coronavirus cause lockdown Around the world"
print(sent.split("_"))
# Out:
# ['coronavirus cause lockdown Around the world']

# %% [markdown]
# Use split function to convert the string into a list of words and save it in variable words and print the same

# %%
sent = "coronavirus cause lockdown Around the world"
words = sent.split()
print(words)
# Out:
# ['coronavirus', 'cause', 'lockdown', 'Around', 'the', 'world']

# %% [markdown]
# Convert each word in the list to lower case and store it in variable words_lower.
# Print words_lower

# %%
sent = "coronavirus cause lockdown Around the world"
words = sent.split()
words_lower = [word.lower() for word in words]
print(words_lower)
# Out:
# ['coronavirus', 'cause', 'lockdown', 'around', 'the', 'world']

# %% [markdown]
# Check whether ‘country’ is in the list

# %%
if "country" in words_lower:
    print("country is present in the list")
else:
    print("country is not in the list")
# Out:
# country is not in the list

# %% [markdown]
# Remove the element ‘the’ from the list and print the list.

# %%
words_lower.remove("the")
print(words_lower)
# Out:
# ['coronavirus', 'cause', 'lockdown', 'around', 'world']

# %% [markdown]
# Select the first 4 words from the list words_lower using slicing and store them in a new variable x4

# %%
x4 = words_lower[:4]
print(x4)
# Out:
# ['coronavirus', 'cause', 'lockdown', 'around']

# %%
print(x4)
# Out:
# ['coronavirus', 'cause', 'lockdown', 'around']

# %% [markdown]
# Convert the list of elements to single string using join function and print it

# %%
x4 = words_lower[:4]
result = " ".join(x4)
print(result)
# Out:
# coronavirus cause lockdown around

# %% [markdown]
# ## Sets

# %% [markdown]
# ### Create stud_grades = ['A','A','B','C','C','F']

# %%
stud_grades = ['A', 'A', 'B', 'C', 'C', 'F']
print(stud_grades)
# Out:
# ['A', 'A', 'B', 'C', 'C', 'F']

# %% [markdown]
# Print the len of stud_grades

# %%
print(len(stud_grades))
# Out:
# 6

# %% [markdown]
# Create a new variable, stud_grades_set = set(stud_grades)

# %%
stud_grades_set = set(stud_grades)
print(stud_grades_set)
# Out:
# {'A', 'C', 'B', 'F'}

# %% [markdown]
# Print stud_grades_set.

# %%
print(stud_grades_set)
# Out:
# {'A', 'C', 'B', 'F'}

# %% [markdown]
# print the type of stud_grades and stud_grades_set and print their corresponding elements. Try to understand the difference between them.

# %%
print(type(stud_grades_set))
print(type(stud_grades_set))
print("Elements in stud_grades:", stud_grades)
print("Elements in stud_grades_set:",stud_grades_set)
# Out:
# <class 'set'>
# <class 'set'>
# Elements in stud_grades: ['A', 'A', 'B', 'C', 'C', 'F']
# Elements in stud_grades_set: {'A', 'C', 'B', 'F'}

# %% [markdown]
# Add a new element ‘G’ to stud_grades_set

# %%
stud_grades_set.add('G')
print(stud_grades_set)
# Out:
# {'C', 'G', 'A', 'F', 'B'}

# %% [markdown]
# Add element 'F' to stud_grades_set. and print it.

# %%
stud_grades_set.add('F')
print(stud_grades_set)
# Out:
# {'C', 'G', 'A', 'F', 'B'}

# %% [markdown]
# !!Did you notice? set doesn't add an element if it's already present in it, unlike lists.

# %%
stud_grades_set = {'A', 'B', 'C', 'F'}
stud_grades_set.add('F')
print(stud_grades_set)
# Out:
# {'A', 'C', 'B', 'F'}

# %% [markdown]
# Remove ‘F’ from stud_grades_set

# %%
stud_grades_set.remove('F')
print(stud_grades_set)
# Out:
# {'A', 'C', 'B'}

# %% [markdown]
# Print the elements and the length of stud_grades_set

# %%
print(stud_grades_set)
print(len(stud_grades_set))
# Out:
# {'A', 'C', 'B'}
# 3

# %% [markdown]
# ### Create colors = [‘red’,’blue’,’orange’], and fruits = [‘orange’,’grapes’,’apples’]

# %%
colors = ['Red', 'Blue', 'Orange']
fruits = ['Apple', 'Orange', 'grapes']
print(colors)
print(fruits)
# Out:
# ['Red', 'Blue', 'Orange']
# ['Apple', 'Orange', 'grapes']

# %% [markdown]
# Print color and fruits

# %%
print(colors)
print(fruits)
# Out:
# ['Red', 'Blue', 'Orange']
# ['Apple', 'Orange', 'grapes']

# %% [markdown]
# Create colors_set, and fruits_set. (using set() ) and print them

# %%
colors_set = set(colors)
fruits_set = set(fruits)
print(colors_set)
print(fruits_set)
# Out:
# {'Red', 'Blue', 'Orange'}
# {'grapes', 'Apple', 'Orange'}

# %% [markdown]
# Find the union of both the sets.

# %%
union_set = colors_set.union(fruits_set)
print(union_set)
# Out:
# {'grapes', 'Red', 'Blue', 'Apple', 'Orange'}

# %% [markdown]
# Find the intersection of both the sets

# %%
intersection_set = colors_set.intersection(fruits_set)
print(intersection_set)
# Out:
# {'Orange'}

# %% [markdown]
# Find the elements which are Fruits but not colors (using set.difference() )

# %%
fruits_not_colors = fruits_set.difference(colors_set)
print(fruits_not_colors)
# Out:
# {'Apple', 'grapes'}

# %% [markdown]
# ## TUPLES

# %% [markdown]
# ### Create temp = [17, ’Virat’, 50.0]

# %%
temp = [17, 'virat', 50.0]
print(temp)
# Out:
# [17, 'virat', 50.0]

# %% [markdown]
# Iterate through temp and print all the items in temp

# %%
for item in temp:
    print(item)
# Out:
# 17
# virat
# 50.0

# %% [markdown]
# replace first element with 11 in temp

# %%
temp[0] = 11
print(temp)
# Out:
# [11, 'virat', 50.0]

# %% [markdown]
# Set temp1 = tuple(temp)

# %%
temp1 = tuple(temp)
print(temp1)
# Out:
# (11, 'virat', 50.0)

# %% [markdown]
# Iterate through temp1 and print all the items in temp1.

# %%
for item in temp:
    print(item)
# Out:
# 11
# virat
# 50.0

# %% [markdown]
# replace first element with 17 in temp1

# %%
temp1 = (17,) + temp1[1:]
print(temp1)
# Out:
# (17, 'virat', 50.0)

# %% [markdown]
# <b>Oops!! You got an error. Hey Don't worry! Its because Once a tuple is created, you cannot change its values unlike list.</b>

# %% [markdown]
# ### Create city = ("Bangalore", 28.9949521, 72)

# %%
city = ("Bangalore", 28.9949521, 72)
print(city)
# Out:
# ('Bangalore', 28.9949521, 72)

# %% [markdown]
# Print first element of city

# %%
print(city[0])
# Out:
# Bangalore

# %% [markdown]
# Create city2 = (‘Chennai’, 30.01, 74)

# %%
city2 = ('chennai', 30.01, 74)
print(city2)
# Out:
# ('chennai', 30.01, 74)

# %% [markdown]
# Create cities which consist of city and city2

# %%
city = ("Bangalore", 28.9949521, 72)
city2 = ('chennai', 30.01, 74)
cities = (city, city2)
print(cities)
# Out:
# (('Bangalore', 28.9949521, 72), ('chennai', 30.01, 74))

# %% [markdown]
# Print cities

# %%
print(cities)
# Out:
# (('Bangalore', 28.9949521, 72), ('chennai', 30.01, 74))

# %% [markdown]
# Print type of first element in cities

# %%
print(type(cities[0]))
# Out:
# <class 'tuple'>

# %% [markdown]
# print the type of cities

# %%
print(type(cities))
# Out:
# <class 'tuple'>

# %% [markdown]
# Hey that implies you made a nested tuples!!

# %% [markdown]
# ## DICTIONARY

# %% [markdown]
# ### Create a dictionary d = {"actor":"amir","animal":"cat","earth":2,"list":[23,32,12]}

# %%
d = {
    "actor": "amir",
    "animal": "cat",
    "earth": 2,
    "list": [23, 32, 12]
}

print(d)
# Out:
# {'actor': 'amir', 'animal': 'cat', 'earth': 2, 'list': [23, 32, 12]}

# %% [markdown]
# Print the value of d[0]

# %%
print(d["actor"])
# Out:
# amir

# %% [markdown]
# <b>Oops!! again an error. again a fun fact. Dictionary return the value for key if key is in the dictionary, else throws KeyError
# and we don't have key 0 here :( </b>

# %% [markdown]
# Store the value of d[‘actor’] to a new variable actor.

# %%
actor = d['actor']
print(actor)
# Out:
# amir

# %% [markdown]
# Print the type of actor

# %%
print(type(actor))
# Out:
# <class 'str'>

# %% [markdown]
# Store the value of d[‘list’] in new variable List.

# %%
list = d['list']
print(list)
# Out:
# [23, 32, 12]

# %% [markdown]
# Print the type of List.

# %%
print(type(list))
# Out:
# <class 'list'>

# %% [markdown]
# Create d1 = { ‘singer’ : ‘Kr$na’ , ‘album’: ‘Still here’, ‘genre’ : ‘hip-hop’}

# %%
d1 = {
    'singer': 'kr$na',
    'album': 'still here',
    'genre': 'hip-hop'
}

print(d1)
# Out:
# {'singer': 'kr$na', 'album': 'still here', 'genre': 'hip-hop'}

# %% [markdown]
# Merge d1 into d.

# %%
d.update(d1)
print(d)
# Out:
# {'actor': 'amir', 'animal': 'cat', 'earth': 2, 'list': [23, 32, 12], 'singer': 'kr$na', 'album': 'still here', 'genre': 'hip-hop'}

# %% [markdown]
# print d

# %%
print(d)
# Out:
# {'actor': 'amir', 'animal': 'cat', 'earth': 2, 'list': [23, 32, 12], 'singer': 'kr$na', 'album': 'still here', 'genre': 'hip-hop'}

# %% [markdown]
# Print all the keys in d

# %%
print(d.keys())
# Out:
# dict_keys(['actor', 'animal', 'earth', 'list', 'singer', 'album', 'genre'])

# %% [markdown]
# Print all the values in d

# %%
print(d.values())
# Out:
# dict_values(['amir', 'cat', 2, [23, 32, 12], 'kr$na', 'still here', 'hip-hop'])

# %% [markdown]
# Iterate over d, and print each key, value pair as this - (actor ----> amir)

# %%
for key, value in d.items():
    print(key, "----->", value)
# Out:
# actor -----> amir
# animal -----> cat
# earth -----> 2
# list -----> [23, 32, 12]
# singer -----> kr$na
# album -----> still here
# genre -----> hip-hop

# %% [markdown]
# count the number of occurences of charachters in string named "sent" using dictionary and print the same.

# %%
for key in d:
    print(key)
# Out:
# actor
# animal
# earth
# list
# singer
# album
# genre
